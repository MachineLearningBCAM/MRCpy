# %%
# %matplotlib inline

# %% [markdown]
# # Hyperparameter Tuning: Upper Bound vs Cross-Validation
#
# Example of how to use the Upper Bounds provided by the `MRC` method in the
# `MRCpy` library for hyperparameter tuning and comparison to Cross-Validation.
# We will see that using the Upper Bound gets similar performances to
# Cross-Validation but being four times faster.
#
# We are using '0-1' loss and `RandomFourierPhi`
# map (`phi='fourier'`). We are going to tune the scaling parameter
# `sigma` and the regularization parameter `s` of the
# feature mapping using a random grid. We will used the usual method
# `RandomizedSearchCV<https://scikit-learn.org/stable/modules/
# generated/sklearn.model_selection.RandomizedSearchCV.html>`
# from `scikit-learn`.
#
# Note that we set the parameter use_cvx=False. In the case of MRC classifiers
# this means that we will use nesterov subgradient optimized approach to
# perform the optimization.

# %%
# Import needed modules
import random
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.spatial import distance
from sklearn import preprocessing
from sklearn.model_selection import RandomizedSearchCV, train_test_split

from MRCpy import MRC
from MRCpy.datasets import *

# %% [markdown]
# ## Random Grid using Upper Bound parameter
# We select random `n_iter` random set of values for the parameters to tune in
# a given range and select the pair of parameters which minimizes the upper
# bound provided by the MRC method.
# On each repetition we calculate and store the upper bound for each possible
# value of sigma.
# The parameter `n_iter` means the amount of randomly selected vectors for the
# parameters to
# tune are chosen. We are selecting `n_iter = 10` because it is the default
# value for the RandomGridCV method.

# %%
def run_RandomGridUpper(X_train, Y_train, X_test, Y_test,
                        s_ini, s_fin, index):
    n_iter = 10
    startTime = time.time()
    #sigma_id = [(sigma_fin - sigma_ini) * random.random() + sigma_ini
    #            for i in range(n_iter)]
    s_id = [(s_fin - s_ini) * random.random() + s_ini for i in range(n_iter)]
    upps = np.zeros(n_iter)

    for i in range(n_iter):
        clf = MRC(phi='fourier', s=s_id[i], random_state=0,
                  deterministic=False, solver='subgrad')
        clf.fit(X_train, Y_train)
        upps[i] = clf.get_upper_bound()

    min_upp = np.min(upps)
    #best_sigma = sigma_id[np.argmin(upps)]
    best_s = s_id[np.argmin(upps)]
    clf = MRC(phi='fourier', s=best_s, random_state=0,
              deterministic=False, solver='subgrad')
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    best_err = np.average(Y_pred != Y_test)
    totalTime = time.time() - startTime

    return pd.DataFrame({'upper': [min_upp], 's': best_s,
            'time': totalTime, 'error': best_err})

# %% [markdown]
# ## RandomGridCV

# %%
def run_RandomGridCV(X_train, Y_train, X_test, Y_test,
                     s_ini, s_fin, index):
    n_iter = 10
    startTime = time.time()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25,
                                                        random_state=rep)
    # Normalizing the data
    std_scale = preprocessing.StandardScaler().fit(X_train, Y_train)
    X_train = std_scale.transform(X_train)
    X_test = std_scale.transform(X_test)

    #sigma_values = np.linspace(sigma_ini, sigma_fin, num=5000)
    s_values = np.linspace(s_ini, s_fin, num=5000)
    param = {'s': s_values}

    mrc = MRC(phi='fourier', random_state=0, deterministic=False,
              solver='subgrad')
    clf = RandomizedSearchCV(mrc, param, random_state=0, n_iter=n_iter)
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    error = np.average(Y_pred != Y_test)

    totalTime = time.time() - startTime

    return pd.DataFrame({'upper': [clf.best_estimator_.get_upper_bound()],
            's': clf.best_estimator_.s,
            'time': totalTime, 'error': error})

# %% [markdown]
# ## Comparison
# We are performing both of the previous methods for hyperparameter tuning
# over a set of different datasets and comparing the performances.
# Before calling them, we set a range of values for the hyperpatameters.
# An intuituve way of choosing sigma is to choose values in the range of the
# distance among the pairs of instances in the trainign set `X_train`.
# Empirical knowledge tells us that best values for s use to be around
# 0.3 and 0.6.
#
# We repeat these processes several times to make sure performances do not
# rely heavily on the train_test_split selected.

# %%
def plot_table(df, title, color):
    fig, ax = plt.subplots()
    # hide axes
    fig.patch.set_visible(False)
    ax.axis('off')
    ax.axis('tight')
    t = ax.table(cellText=df.values, colLabels=df.columns, loc='center',
                 colColours=color, cellColours=[color] * len(df))
    t.auto_set_font_size(False)
    t.set_fontsize(8)
    t.auto_set_column_width(col=list(range(len(df.columns))))
    fig.tight_layout()
    plt.title(title)
    plt.show()


loaders = [load_mammographic, load_haberman, load_indian_liver,
           load_diabetes, load_credit]
dataNameList = ["mammographic", "haberman", "indian_liver",
                "diabetes", "credit"]

dfCV = pd.DataFrame()
dfUpper = pd.DataFrame()
f = '%1.3g'  # format
for j, load in enumerate(loaders):

    # Loading the dataset
    X, Y = load()
    dataName = dataNameList[j]

    # In order to avoid the possible bias made by the choice of the train-test
    # split, we do this process several (20) times and average the
    # obtained results
    dfCV_aux = pd.DataFrame()
    dfUpper_aux = pd.DataFrame()
    for rep in range(10):
        X_train, X_test, Y_train, Y_test = \
            train_test_split(X, Y, test_size=0.25, random_state=rep)
        # Normalizing the data
        std_scale = preprocessing.StandardScaler().fit(X_train, Y_train)
        X_train = std_scale.transform(X_train)
        X_test = std_scale.transform(X_test)

        # Select an appropiate range for sigma
        d = np.triu(distance.cdist(X_train, X_train)).flatten()
        d = d[d != 0]
        d.sort()
        #sigma_ini = d[int(len(d) * 0.1)]
        #sigma_fin = d[int(len(d) * 0.3)]
        s_ini = 0.3
        s_fin = 0.6

        # We tune the parameters using both method and store the results
        # dfCV_aux = dfCV_aux.append(
        #     run_RandomGridCV(X_train, Y_train, X_test, Y_test,
        #                      s_ini, s_fin, rep), ignore_index=True)
        dfCV_aux = pd.concat([dfCV_aux,
            run_RandomGridCV(X_train, Y_train, X_test, Y_test,
                             s_ini, s_fin, rep)], ignore_index=True)
        dfUpper_aux = pd.concat([dfUpper_aux,
            run_RandomGridUpper(X_train, Y_train, X_test, Y_test,
                                s_ini, s_fin, rep)], ignore_index=True)

    # We save the mean results of the 20 repetitions
    mean_err = f % np.mean(dfCV_aux['error']) + ' ± ' + \
        f % np.std(dfCV_aux['error'])
    mean_s = f % np.mean(dfCV_aux['s']) + ' ± ' + f % np.std(dfCV_aux['s'])
    mean_time = f % np.mean(dfCV_aux['time']) + ' ± ' + \
        f % np.std(dfCV_aux['time'])
    mean_upper = f % np.mean(dfCV_aux['upper']) + ' ± ' + \
        f % np.std(dfCV_aux['upper'])
    dfCV = pd.concat([dfCV, pd.DataFrame({'dataset': [dataName], 'error': mean_err,
                        's': mean_s,
                        'upper': mean_upper,
                        'time': mean_time})], ignore_index=True)
    mean_err = f % np.mean(dfUpper_aux['error']) + ' ± ' + \
        f % np.std(dfUpper_aux['error'])
    mean_s = f % np.mean(dfUpper_aux['s']) + ' ± ' + \
        f % np.std(dfUpper_aux['s'])
    mean_time = f % np.mean(dfUpper_aux['time']) + ' ± ' + \
        f % np.std(dfUpper_aux['time'])
    mean_upper = f % np.mean(dfUpper_aux['upper']) + ' ± ' + \
        f % np.std(dfUpper_aux['upper'])
    dfUpper = pd.concat([dfUpper, pd.DataFrame({'dataset': [dataName], 'error': mean_err,
                              's': mean_s,
                              'upper': mean_upper,
                              'time': mean_time})], ignore_index=True)
# Out:
# The upper bound for non deterministic is :  0.23325630324878727
# The upper bound for non deterministic is :  0.23635540469890748
# The upper bound for non deterministic is :  0.2313783976909462
# The upper bound for non deterministic is :  0.2307949383442378
# The upper bound for non deterministic is :  0.23930578609285358
# The upper bound for non deterministic is :  0.23299094089929046
# The upper bound for non deterministic is :  0.23608374118182995
# The upper bound for non deterministic is :  0.2311356845661044
# The upper bound for non deterministic is :  0.23057488005885973
# The upper bound for non deterministic is :  0.23905688291161897
# The upper bound for non deterministic is :  0.23102243602500167
# The upper bound for non deterministic is :  0.23386932530656518
# The upper bound for non deterministic is :  0.22912457058581565
# The upper bound for non deterministic is :  0.2286647150794789
# The upper bound for non deterministic is :  0.23702662493358523
# The upper bound for non deterministic is :  0.23433372667410474
# The upper bound for non deterministic is :  0.23751979689185376
# The upper bound for non deterministic is :  0.2324312755785924
# The upper bound for non deterministic is :  0.23178906347476197
# The upper bound for non deterministic is :  0.24041031156502124
# The upper bound for non deterministic is :  0.2375492765857028
# The upper bound for non deterministic is :  0.24090287161813617
# The upper bound for non deterministic is :  0.23554838680270723
# The upper bound for non deterministic is :  0.23467322171980887
# The upper bound for non deterministic is :  0.2436422113599525
# The upper bound for non deterministic is :  0.23740354355978077
# The upper bound for non deterministic is :  0.24077221382541292
# The upper bound for non deterministic is :  0.2354142254994263
# The upper bound for non deterministic is :  0.23454699865490347
# The upper bound for non deterministic is :  0.2434956964767106
# The upper bound for non deterministic is :  0.22968348597276533
# The upper bound for non deterministic is :  0.23238266334990804
# The upper bound for non deterministic is :  0.22771105041510642
# The upper bound for non deterministic is :  0.22736320663756543
# The upper bound for non deterministic is :  0.23560736147535594
# The upper bound for non deterministic is :  0.23651593742879462
# The upper bound for non deterministic is :  0.2398115439821381
# The upper bound for non deterministic is :  0.23448300192426796
# The upper bound for non deterministic is :  0.23373860807321584
# The upper bound for non deterministic is :  0.24259361106390276
# The upper bound for non deterministic is :  0.2347409647088745
# The upper bound for non deterministic is :  0.23795014854754426
# The upper bound for non deterministic is :  0.23283496074974402
# The upper bound for non deterministic is :  0.2321702788069238
# The upper bound for non deterministic is :  0.24081562464453515
# The upper bound for non deterministic is :  0.22893472444045265
# The upper bound for non deterministic is :  0.23157539239929387
# The upper bound for non deterministic is :  0.22694209421843414
# The upper bound for non deterministic is :  0.2266534230795944
# The upper bound for non deterministic is :  0.2348366135610334
# The upper bound for non deterministic is :  0.2310047618645671
# The upper bound for non deterministic is :  0.2362148226434383
# The upper bound for non deterministic is :  0.23668563705298507
# The upper bound for non deterministic is :  0.23864631329608543
# The upper bound for non deterministic is :  0.23261997719656735
# The upper bound for non deterministic is :  0.23819571889944263
# The upper bound for non deterministic is :  0.23130463037541882
# The upper bound for non deterministic is :  0.23305406363296083
# The upper bound for non deterministic is :  0.23605954074648583
# The upper bound for non deterministic is :  0.23493994683481584
# The upper bound for non deterministic is :  0.2368290915661067
# The upper bound for non deterministic is :  0.23130463037541882
# The upper bound for non deterministic is :  0.21335980272858157
# The upper bound for non deterministic is :  0.2027694000042135
# The upper bound for non deterministic is :  0.2138272629314783
# The upper bound for non deterministic is :  0.22337139934276423
# The upper bound for non deterministic is :  0.20540840289710371
# The upper bound for non deterministic is :  0.21309696403138922
# The upper bound for non deterministic is :  0.20252061301421476
# The upper bound for non deterministic is :  0.2135404011526441
# The upper bound for non deterministic is :  0.22309251118487167
# The upper bound for non deterministic is :  0.20511792443520938
# The upper bound for non deterministic is :  0.21094884901075517
# The upper bound for non deterministic is :  0.20041565356739693
# The upper bound for non deterministic is :  0.21137774823972622
# The upper bound for non deterministic is :  0.22100571885912662
# The upper bound for non deterministic is :  0.20285193353271808
# The upper bound for non deterministic is :  0.21455236028030406
# The upper bound for non deterministic is :  0.2038791587642652
# The upper bound for non deterministic is :  0.2150001766761182
# The upper bound for non deterministic is :  0.2245201067553645
# The upper bound for non deterministic is :  0.20660052910810467
# The upper bound for non deterministic is :  0.2180946117007161
# The upper bound for non deterministic is :  0.20741007909997267
# The upper bound for non deterministic is :  0.21863358807399452
# The upper bound for non deterministic is :  0.228102183054671
# The upper bound for non deterministic is :  0.2102090911873089
# The upper bound for non deterministic is :  0.21795735784715897
# The upper bound for non deterministic is :  0.20726092640458177
# The upper bound for non deterministic is :  0.21848536860126172
# The upper bound for non deterministic is :  0.22794206805031175
# The upper bound for non deterministic is :  0.21004471996265273
# The upper bound for non deterministic is :  0.20949575989203745
# The upper bound for non deterministic is :  0.19903987756048114
# The upper bound for non deterministic is :  0.20989031213512227
# The upper bound for non deterministic is :  0.21961759817783044
# The upper bound for non deterministic is :  0.20123193797616906
# The upper bound for non deterministic is :  0.21695048026191244
# The upper bound for non deterministic is :  0.20624397999900995
# The upper bound for non deterministic is :  0.21741496850792003
# The upper bound for non deterministic is :  0.22688816537226048
# The upper bound for non deterministic is :  0.2090094924023047
# The upper bound for non deterministic is :  0.21499977530030334
# The upper bound for non deterministic is :  0.20431904836755643
# The upper bound for non deterministic is :  0.21546132324678952
# The upper bound for non deterministic is :  0.2249557419239676
# The upper bound for non deterministic is :  0.2070646145501262
# The upper bound for non deterministic is :  0.20871822625272168
# The upper bound for non deterministic is :  0.19828022756891273
# The upper bound for non deterministic is :  0.20910359313339205
# The upper bound for non deterministic is :  0.21887957893315413
# The upper bound for non deterministic is :  0.20036238595329242
# The upper bound for non deterministic is :  0.21256476561168758
# The upper bound for non deterministic is :  0.21091405138488878
# The upper bound for non deterministic is :  0.20762378942784132
# The upper bound for non deterministic is :  0.2137038123864593
# The upper bound for non deterministic is :  0.21312174751130286
# The upper bound for non deterministic is :  0.2080151663192466
# The upper bound for non deterministic is :  0.20644670293074396
# The upper bound for non deterministic is :  0.20944564382790531
# The upper bound for non deterministic is :  0.21009964427008487
# The upper bound for non deterministic is :  0.21321931903996733
# The upper bound for non deterministic is :  0.20604814803084842
# The upper bound for non deterministic is :  0.20604814803084842
# The upper bound for non deterministic is :  0.22284177640613145
# The upper bound for non deterministic is :  0.21744843452828055
# The upper bound for non deterministic is :  0.21923253449331587
# The upper bound for non deterministic is :  0.21110768854694817
# The upper bound for non deterministic is :  0.21172272304313283
# The upper bound for non deterministic is :  0.22256173901222914
# The upper bound for non deterministic is :  0.21711876469267594
# The upper bound for non deterministic is :  0.2189468917731418
# The upper bound for non deterministic is :  0.21076071948061487
# The upper bound for non deterministic is :  0.21140477794780538
# The upper bound for non deterministic is :  0.22038289777841696
# The upper bound for non deterministic is :  0.21451685566533707
# The upper bound for non deterministic is :  0.2166689051123027
# The upper bound for non deterministic is :  0.20819644051261088
# The upper bound for non deterministic is :  0.2089631295722928
# The upper bound for non deterministic is :  0.2239934951497466
# The upper bound for non deterministic is :  0.21879673040016684
# The upper bound for non deterministic is :  0.2203906104078402
# The upper bound for non deterministic is :  0.21251485432149403
# The upper bound for non deterministic is :  0.21300552717242438
# The upper bound for non deterministic is :  0.2274662789258462
# The upper bound for non deterministic is :  0.22278081780297487
# The upper bound for non deterministic is :  0.2242337762317353
# The upper bound for non deterministic is :  0.21655245085384728
# The upper bound for non deterministic is :  0.21676198799179525
# The upper bound for non deterministic is :  0.22731414753455864
# The upper bound for non deterministic is :  0.22261579504562584
# The upper bound for non deterministic is :  0.22408365398769592
# The upper bound for non deterministic is :  0.2163938905014718
# The upper bound for non deterministic is :  0.21659396458337382
# The upper bound for non deterministic is :  0.21888095038385424
# The upper bound for non deterministic is :  0.21277237914186753
# The upper bound for non deterministic is :  0.21505117518955613
# The upper bound for non deterministic is :  0.2064632049914989
# The upper bound for non deterministic is :  0.20727070124236785
# The upper bound for non deterministic is :  0.22634862689822838
# The upper bound for non deterministic is :  0.22148001157285468
# The upper bound for non deterministic is :  0.22297912227014932
# The upper bound for non deterministic is :  0.2152524791125276
# The upper bound for non deterministic is :  0.21553843053159755
# The upper bound for non deterministic is :  0.22443989023322608
# The upper bound for non deterministic is :  0.21932131162904345
# The upper bound for non deterministic is :  0.22087238770105022
# The upper bound for non deterministic is :  0.21302885819340256
# The upper bound for non deterministic is :  0.21347283257754457
# The upper bound for non deterministic is :  0.21807711058756096
# The upper bound for non deterministic is :  0.21173340091890996
# The upper bound for non deterministic is :  0.2141981204038454
# The upper bound for non deterministic is :  0.20550646679903278
# The upper bound for non deterministic is :  0.20632651929956358
# The upper bound for non deterministic is :  0.2161990147965031
# The upper bound for non deterministic is :  0.21783679455398058
# The upper bound for non deterministic is :  0.21190774387768646
# The upper bound for non deterministic is :  0.2195028688505501
# The upper bound for non deterministic is :  0.21304428584695678
# The upper bound for non deterministic is :  0.21343044651700438
# The upper bound for non deterministic is :  0.2197848675501049
# The upper bound for non deterministic is :  0.221126190655348
# The upper bound for non deterministic is :  0.21831234700090374
# The upper bound for non deterministic is :  0.21165047433688278
# The upper bound for non deterministic is :  0.21609928480362683
# The upper bound for non deterministic is :  0.21165047433688278
# The upper bound for non deterministic is :  0.23250188417961382
# The upper bound for non deterministic is :  0.233749934127288
# The upper bound for non deterministic is :  0.24989236964194328
# The upper bound for non deterministic is :  0.23287673059115405
# The upper bound for non deterministic is :  0.24009632337197484
# The upper bound for non deterministic is :  0.23223213373746032
# The upper bound for non deterministic is :  0.23350123657764327
# The upper bound for non deterministic is :  0.24962240795061824
# The upper bound for non deterministic is :  0.23261893040171094
# The upper bound for non deterministic is :  0.23986330436494996
# The upper bound for non deterministic is :  0.23020326926960405
# The upper bound for non deterministic is :  0.23158651409550168
# The upper bound for non deterministic is :  0.24755626343076126
# The upper bound for non deterministic is :  0.2307783433702396
# The upper bound for non deterministic is :  0.23792498056342587
# The upper bound for non deterministic is :  0.23365765751665707
# The upper bound for non deterministic is :  0.2347675061262401
# The upper bound for non deterministic is :  0.25099965378652733
# The upper bound for non deterministic is :  0.23382588342479704
# The upper bound for non deterministic is :  0.24110906043735575
# The upper bound for non deterministic is :  0.23701052987587062
# The upper bound for non deterministic is :  0.23780062237880017
# The upper bound for non deterministic is :  0.25423513461253167
# The upper bound for non deterministic is :  0.23678348874513938
# The upper bound for non deterministic is :  0.24409060392829884
# The upper bound for non deterministic is :  0.2368820074292815
# The upper bound for non deterministic is :  0.23765941816115538
# The upper bound for non deterministic is :  0.25408668552424607
# The upper bound for non deterministic is :  0.23666316948507393
# The upper bound for non deterministic is :  0.24396760992469768
# The upper bound for non deterministic is :  0.22874630886416253
# The upper bound for non deterministic is :  0.23030579599182427
# The upper bound for non deterministic is :  0.2461066294208794
# The upper bound for non deterministic is :  0.22949672649344133
# The upper bound for non deterministic is :  0.23662263135302403
# The upper bound for non deterministic is :  0.2359207105447716
# The upper bound for non deterministic is :  0.23682537025679418
# The upper bound for non deterministic is :  0.25317993673766415
# The upper bound for non deterministic is :  0.23583675229892342
# The upper bound for non deterministic is :  0.24313418385511149
# The upper bound for non deterministic is :  0.23407730326519982
# The upper bound for non deterministic is :  0.23513918641942966
# The upper bound for non deterministic is :  0.25141641193671
# The upper bound for non deterministic is :  0.23420267080288376
# The upper bound for non deterministic is :  0.24148091823301565
# The upper bound for non deterministic is :  0.2279622644616277
# The upper bound for non deterministic is :  0.22960139230997423
# The upper bound for non deterministic is :  0.24528986083282212
# The upper bound for non deterministic is :  0.22879469395316876
# The upper bound for non deterministic is :  0.23590256229214562
# The upper bound for non deterministic is :  0.23708775611531346
# The upper bound for non deterministic is :  0.2360242696158273
# The upper bound for non deterministic is :  0.2366365529289069
# The upper bound for non deterministic is :  0.23226210637451328
# The upper bound for non deterministic is :  0.2381916243906012
# The upper bound for non deterministic is :  0.23296087854461345
# The upper bound for non deterministic is :  0.23298111242597874
# The upper bound for non deterministic is :  0.2376181427910598
# The upper bound for non deterministic is :  0.2339970143245933
# The upper bound for non deterministic is :  0.23800066742406134
# The upper bound for non deterministic is :  0.2326715986503745
# The upper bound for non deterministic is :  0.23226210637451328
# The upper bound for non deterministic is :  0.2050100500940244
# The upper bound for non deterministic is :  0.20254993454332842
# The upper bound for non deterministic is :  0.20035309358150677
# The upper bound for non deterministic is :  0.211357808764141
# The upper bound for non deterministic is :  0.20727480100307394
# The upper bound for non deterministic is :  0.2047550094401588
# The upper bound for non deterministic is :  0.20225221176237906
# The upper bound for non deterministic is :  0.20006249165279555
# The upper bound for non deterministic is :  0.21110033869143963
# The upper bound for non deterministic is :  0.2070032703648878
# The upper bound for non deterministic is :  0.20279158544154674
# The upper bound for non deterministic is :  0.20003527328034665
# The upper bound for non deterministic is :  0.19778970658474515
# The upper bound for non deterministic is :  0.20900597619621342
# The upper bound for non deterministic is :  0.204902299310385
# The upper bound for non deterministic is :  0.20608084751339695
# The upper bound for non deterministic is :  0.20377582737888794
# The upper bound for non deterministic is :  0.20154578575647625
# The upper bound for non deterministic is :  0.21250022987489808
# The upper bound for non deterministic is :  0.2084023918339163
# The upper bound for non deterministic is :  0.20927952513008785
# The upper bound for non deterministic is :  0.20732053357791663
# The upper bound for non deterministic is :  0.2051783050686694
# The upper bound for non deterministic is :  0.21590904847135028
# The upper bound for non deterministic is :  0.2116980138052051
# The upper bound for non deterministic is :  0.20913570646241458
# The upper bound for non deterministic is :  0.20717148888601739
# The upper bound for non deterministic is :  0.20502664550458877
# The upper bound for non deterministic is :  0.21574719796399167
# The upper bound for non deterministic is :  0.21157068000846535
# The upper bound for non deterministic is :  0.20147603972765704
# The upper bound for non deterministic is :  0.1985293880390418
# The upper bound for non deterministic is :  0.19627355770413768
# The upper bound for non deterministic is :  0.20758076831175348
# The upper bound for non deterministic is :  0.20345576060877135
# The upper bound for non deterministic is :  0.20822351210765505
# The upper bound for non deterministic is :  0.20616303003711844
# The upper bound for non deterministic is :  0.20397845226591255
# The upper bound for non deterministic is :  0.21480027574953942
# The upper bound for non deterministic is :  0.21061151466674932
# The upper bound for non deterministic is :  0.2064799921318986
# The upper bound for non deterministic is :  0.2042396221229864
# The upper bound for non deterministic is :  0.20197487836456918
# The upper bound for non deterministic is :  0.21295656098564836
# The upper bound for non deterministic is :  0.20882394684269123
# The upper bound for non deterministic is :  0.20075647616487036
# The upper bound for non deterministic is :  0.19771211407269235
# The upper bound for non deterministic is :  0.19545256422727175
# The upper bound for non deterministic is :  0.20681884693503932
# The upper bound for non deterministic is :  0.20266742541731103
# The upper bound for non deterministic is :  0.2018496914909783
# The upper bound for non deterministic is :  0.20467812988202339
# The upper bound for non deterministic is :  0.2093514028826447
# The upper bound for non deterministic is :  0.2036226375201431
# The upper bound for non deterministic is :  0.20671426877313503
# The upper bound for non deterministic is :  0.2073571689937685
# The upper bound for non deterministic is :  0.20904732062646808
# The upper bound for non deterministic is :  0.20024809540430788
# The upper bound for non deterministic is :  0.2082377060068198
# The upper bound for non deterministic is :  0.20250374158769113
# The upper bound for non deterministic is :  0.2059936266122031
# The upper bound for non deterministic is :  0.20024809540430788
# The upper bound for non deterministic is :  0.22875263551921166
# The upper bound for non deterministic is :  0.24215030850289537
# The upper bound for non deterministic is :  0.2404630057703857
# The upper bound for non deterministic is :  0.23187197296138023
# The upper bound for non deterministic is :  0.23086475188678562
# The upper bound for non deterministic is :  0.22852142246574625
# The upper bound for non deterministic is :  0.24191780261225793
# The upper bound for non deterministic is :  0.2401840069525037
# The upper bound for non deterministic is :  0.2315832041700862
# The upper bound for non deterministic is :  0.2306314578563186
# The upper bound for non deterministic is :  0.22655105336131692
# The upper bound for non deterministic is :  0.24008425513817488
# The upper bound for non deterministic is :  0.2381609301947895
# The upper bound for non deterministic is :  0.22931765547891608
# The upper bound for non deterministic is :  0.2287038442152889
# The upper bound for non deterministic is :  0.22976104530056035
# The upper bound for non deterministic is :  0.2431076265324561
# The upper bound for non deterministic is :  0.24156645754984696
# The upper bound for non deterministic is :  0.2330396600626662
# The upper bound for non deterministic is :  0.23186311769429907
# The upper bound for non deterministic is :  0.2327985076380722
# The upper bound for non deterministic is :  0.24614098886488717
# The upper bound for non deterministic is :  0.244807992926745
# The upper bound for non deterministic is :  0.23647460801111575
# The upper bound for non deterministic is :  0.23485443170746517
# The upper bound for non deterministic is :  0.23266014524875328
# The upper bound for non deterministic is :  0.24599806593925921
# The upper bound for non deterministic is :  0.24465256055649004
# The upper bound for non deterministic is :  0.23633260561282782
# The upper bound for non deterministic is :  0.2347208281250358
# The upper bound for non deterministic is :  0.22519838852833746
# The upper bound for non deterministic is :  0.23881106348762948
# The upper bound for non deterministic is :  0.23683535935681965
# The upper bound for non deterministic is :  0.22778825557637017
# The upper bound for non deterministic is :  0.22738180956395515
# The upper bound for non deterministic is :  0.23180415220599904
# The upper bound for non deterministic is :  0.24513021041395971
# The upper bound for non deterministic is :  0.24372093472490708
# The upper bound for non deterministic is :  0.23536122091085576
# The upper bound for non deterministic is :  0.23389016908689242
# The upper bound for non deterministic is :  0.23015738408150543
# The upper bound for non deterministic is :  0.24349305452914655
# The upper bound for non deterministic is :  0.24195393967873963
# The upper bound for non deterministic is :  0.23348442483623633
# The upper bound for non deterministic is :  0.2322291788559122
# The upper bound for non deterministic is :  0.2244427476487938
# The upper bound for non deterministic is :  0.2381514069890669
# The upper bound for non deterministic is :  0.23607303047632872
# The upper bound for non deterministic is :  0.22702773041987223
# The upper bound for non deterministic is :  0.22666701878986195
# The upper bound for non deterministic is :  0.23170503293049882
# The upper bound for non deterministic is :  0.22995498219624388
# The upper bound for non deterministic is :  0.23709559785876744
# The upper bound for non deterministic is :  0.231554685972234
# The upper bound for non deterministic is :  0.23384689352238708
# The upper bound for non deterministic is :  0.23763469223046269
# The upper bound for non deterministic is :  0.23465911440853687
# The upper bound for non deterministic is :  0.2301997224752284
# The upper bound for non deterministic is :  0.23833444443209761
# The upper bound for non deterministic is :  0.2300833806651047
# The upper bound for non deterministic is :  0.23466044435692024
# The upper bound for non deterministic is :  0.22995498219624388
# The upper bound for non deterministic is :  0.23451511126362018
# The upper bound for non deterministic is :  0.2413978649957388
# The upper bound for non deterministic is :  0.23312412607494815
# The upper bound for non deterministic is :  0.2442144187792507
# The upper bound for non deterministic is :  0.2369978452329216
# The upper bound for non deterministic is :  0.23427407240412734
# The upper bound for non deterministic is :  0.24114440768159323
# The upper bound for non deterministic is :  0.23289940903120687
# The upper bound for non deterministic is :  0.24398815427000298
# The upper bound for non deterministic is :  0.23675356824874827
# The upper bound for non deterministic is :  0.2324108095595872
# The upper bound for non deterministic is :  0.23910322577845666
# The upper bound for non deterministic is :  0.23115058368745428
# The upper bound for non deterministic is :  0.24212267166671048
# The upper bound for non deterministic is :  0.234774676538811
# The upper bound for non deterministic is :  0.23554886744087805
# The upper bound for non deterministic is :  0.24248373309039206
# The upper bound for non deterministic is :  0.23405854342131704
# The upper bound for non deterministic is :  0.2452516454765698
# The upper bound for non deterministic is :  0.2380392477390617
# The upper bound for non deterministic is :  0.23849550030610434
# The upper bound for non deterministic is :  0.24570252530523895
# The upper bound for non deterministic is :  0.23684589589013555
# The upper bound for non deterministic is :  0.24829179078368518
# The upper bound for non deterministic is :  0.24107427126689224
# The upper bound for non deterministic is :  0.23837821061751502
# The upper bound for non deterministic is :  0.24557083253876266
# The upper bound for non deterministic is :  0.23672571916174645
# The upper bound for non deterministic is :  0.2481948549094446
# The upper bound for non deterministic is :  0.24095113448793648
# The upper bound for non deterministic is :  0.2310947054081895
# The upper bound for non deterministic is :  0.2377159898103855
# The upper bound for non deterministic is :  0.22994471661597488
# The upper bound for non deterministic is :  0.2408271606165731
# The upper bound for non deterministic is :  0.23342380050574224
# The upper bound for non deterministic is :  0.23755865839604728
# The upper bound for non deterministic is :  0.24463075975524984
# The upper bound for non deterministic is :  0.2359270867733917
# The upper bound for non deterministic is :  0.24728257448259705
# The upper bound for non deterministic is :  0.24007117664658711
# The upper bound for non deterministic is :  0.23592910660679284
# The upper bound for non deterministic is :  0.24288645198337455
# The upper bound for non deterministic is :  0.23440155485591146
# The upper bound for non deterministic is :  0.2456186773634333
# The upper bound for non deterministic is :  0.23842641589130625
# The upper bound for non deterministic is :  0.2304053347752157
# The upper bound for non deterministic is :  0.23695488511905188
# The upper bound for non deterministic is :  0.2292859043033667
# The upper bound for non deterministic is :  0.2400991332825969
# The upper bound for non deterministic is :  0.23266395387032995
# The upper bound for non deterministic is :  0.2411137872894017
# The upper bound for non deterministic is :  0.23386945597166442
# The upper bound for non deterministic is :  0.2390217296080454
# The upper bound for non deterministic is :  0.24150353916931105
# The upper bound for non deterministic is :  0.23697407496632605
# The upper bound for non deterministic is :  0.24169542185408194
# The upper bound for non deterministic is :  0.23397447638828633
# The upper bound for non deterministic is :  0.2351189090781176
# The upper bound for non deterministic is :  0.23427609836370605
# The upper bound for non deterministic is :  0.23819803331521172
# The upper bound for non deterministic is :  0.23817592891727857
# The upper bound for non deterministic is :  0.23386945597166442
# The upper bound for non deterministic is :  0.24003353401698774
# The upper bound for non deterministic is :  0.23646708209514783
# The upper bound for non deterministic is :  0.2380167231875937
# The upper bound for non deterministic is :  0.24153967551786537
# The upper bound for non deterministic is :  0.24347572846525767
# The upper bound for non deterministic is :  0.2397879632110243
# The upper bound for non deterministic is :  0.2362246614644663
# The upper bound for non deterministic is :  0.2377739139836062
# The upper bound for non deterministic is :  0.2412859166820367
# The upper bound for non deterministic is :  0.2432358357920127
# The upper bound for non deterministic is :  0.23783503169546977
# The upper bound for non deterministic is :  0.23422532666785467
# The upper bound for non deterministic is :  0.23599708843873018
# The upper bound for non deterministic is :  0.23944053087154865
# The upper bound for non deterministic is :  0.24133493200020983
# The upper bound for non deterministic is :  0.24104943258384415
# The upper bound for non deterministic is :  0.23752280990890112
# The upper bound for non deterministic is :  0.2389631682742988
# The upper bound for non deterministic is :  0.2425493667420125
# The upper bound for non deterministic is :  0.24448184886458313
# The upper bound for non deterministic is :  0.24407472083885207
# The upper bound for non deterministic is :  0.24058289233162733
# The upper bound for non deterministic is :  0.24177472989372922
# The upper bound for non deterministic is :  0.24556869328165282
# The upper bound for non deterministic is :  0.24749353804378438
# The upper bound for non deterministic is :  0.2439612805326803
# The upper bound for non deterministic is :  0.24045779614614132
# The upper bound for non deterministic is :  0.24166348053422332
# The upper bound for non deterministic is :  0.2454432300610635
# The upper bound for non deterministic is :  0.24736422113882944
# The upper bound for non deterministic is :  0.23649446654395634
# The upper bound for non deterministic is :  0.23285948652156419
# The upper bound for non deterministic is :  0.2347803211798476
# The upper bound for non deterministic is :  0.23819417743515137
# The upper bound for non deterministic is :  0.2400169815769354
# The upper bound for non deterministic is :  0.2430873188640429
# The upper bound for non deterministic is :  0.23958354226553852
# The upper bound for non deterministic is :  0.2408609545790757
# The upper bound for non deterministic is :  0.2445857193806451
# The upper bound for non deterministic is :  0.2465030823431848
# The upper bound for non deterministic is :  0.2414369448736715
# The upper bound for non deterministic is :  0.2379071245191881
# The upper bound for non deterministic is :  0.2393067456543591
# The upper bound for non deterministic is :  0.2429274529239812
# The upper bound for non deterministic is :  0.24485955340134458
# The upper bound for non deterministic is :  0.23574889830540924
# The upper bound for non deterministic is :  0.232138901060774
# The upper bound for non deterministic is :  0.23412329438801616
# The upper bound for non deterministic is :  0.23753238945584615
# The upper bound for non deterministic is :  0.2393502066809864
# The upper bound for non deterministic is :  0.23998660389641657
# The upper bound for non deterministic is :  0.2432864878836743
# The upper bound for non deterministic is :  0.23659018160780781
# The upper bound for non deterministic is :  0.240057040570262
# The upper bound for non deterministic is :  0.24284655943881206
# The upper bound for non deterministic is :  0.24285727056035877
# The upper bound for non deterministic is :  0.23898901108343112
# The upper bound for non deterministic is :  0.24223893877429192
# The upper bound for non deterministic is :  0.2395387384834501
# The upper bound for non deterministic is :  0.24280008431151978
# The upper bound for non deterministic is :  0.241053431433491
# The upper bound for non deterministic is :  0.23659018160780781
# The upper bound for non deterministic is :  0.22952513080193127
# The upper bound for non deterministic is :  0.23532802989637053
# The upper bound for non deterministic is :  0.22451004796949942
# The upper bound for non deterministic is :  0.22482035954568158
# The upper bound for non deterministic is :  0.2300099392429889
# The upper bound for non deterministic is :  0.2292296183529861
# The upper bound for non deterministic is :  0.23507665268799627
# The upper bound for non deterministic is :  0.22427912564832825
# The upper bound for non deterministic is :  0.22458573808390525
# The upper bound for non deterministic is :  0.2297324828399802
# The upper bound for non deterministic is :  0.22713492582022066
# The upper bound for non deterministic is :  0.2330864858268648
# The upper bound for non deterministic is :  0.22241155909806976
# The upper bound for non deterministic is :  0.2227378440463273
# The upper bound for non deterministic is :  0.22747420786856942
# The upper bound for non deterministic is :  0.23063101371462646
# The upper bound for non deterministic is :  0.2363789885582167
# The upper bound for non deterministic is :  0.22551509876984455
# The upper bound for non deterministic is :  0.22580457529020082
# The upper bound for non deterministic is :  0.23117194698652294
# The upper bound for non deterministic is :  0.23388298980657457
# The upper bound for non deterministic is :  0.23950119604906667
# The upper bound for non deterministic is :  0.2283761742902557
# The upper bound for non deterministic is :  0.2288810188396707
# The upper bound for non deterministic is :  0.23461882760830244
# The upper bound for non deterministic is :  0.2337577091981914
# The upper bound for non deterministic is :  0.23936649458291903
# The upper bound for non deterministic is :  0.2282465010311433
# The upper bound for non deterministic is :  0.22876221149395332
# The upper bound for non deterministic is :  0.23447614566773395
# The upper bound for non deterministic is :  0.22569176115345763
# The upper bound for non deterministic is :  0.23170358480818293
# The upper bound for non deterministic is :  0.22111271460014298
# The upper bound for non deterministic is :  0.2214108217386217
# The upper bound for non deterministic is :  0.22598114369461791
# The upper bound for non deterministic is :  0.23283949030735596
# The upper bound for non deterministic is :  0.23846251917544486
# The upper bound for non deterministic is :  0.22744453176210122
# The upper bound for non deterministic is :  0.22787693121839026
# The upper bound for non deterministic is :  0.2334783294496734
# The upper bound for non deterministic is :  0.23105214254555678
# The upper bound for non deterministic is :  0.2367788538491049
# The upper bound for non deterministic is :  0.22588621599000003
# The upper bound for non deterministic is :  0.2261933912156624
# The upper bound for non deterministic is :  0.2316116234917447
# The upper bound for non deterministic is :  0.22490393152886257
# The upper bound for non deterministic is :  0.23093660425008733
# The upper bound for non deterministic is :  0.22040842404701616
# The upper bound for non deterministic is :  0.22070191307343018
# The upper bound for non deterministic is :  0.22515619891164423
# The upper bound for non deterministic is :  0.2252004144545367
# The upper bound for non deterministic is :  0.22305307273126568
# The upper bound for non deterministic is :  0.2305493479786847
# The upper bound for non deterministic is :  0.22582997954214862
# The upper bound for non deterministic is :  0.22591693292531378
# The upper bound for non deterministic is :  0.22473760351491334
# The upper bound for non deterministic is :  0.22425916861230383
# The upper bound for non deterministic is :  0.23061381372562895
# The upper bound for non deterministic is :  0.2277078502215265
# The upper bound for non deterministic is :  0.23126807961044749
# The upper bound for non deterministic is :  0.2255617344633088
# The upper bound for non deterministic is :  0.22305307273126568
# The upper bound for non deterministic is :  0.23019698342839107
# The upper bound for non deterministic is :  0.23185956384774042
# The upper bound for non deterministic is :  0.2351522242430667
# The upper bound for non deterministic is :  0.24458325046183543
# The upper bound for non deterministic is :  0.24418875157765207
# The upper bound for non deterministic is :  0.22995062629768181
# The upper bound for non deterministic is :  0.23159624120641553
# The upper bound for non deterministic is :  0.23490839845536493
# The upper bound for non deterministic is :  0.24433230888285995
# The upper bound for non deterministic is :  0.24393979390587417
# The upper bound for non deterministic is :  0.2281040469808
# The upper bound for non deterministic is :  0.2295367171160283
# The upper bound for non deterministic is :  0.23303336312774647
# The upper bound for non deterministic is :  0.24238448428389436
# The upper bound for non deterministic is :  0.24209830512710018
# The upper bound for non deterministic is :  0.2311444079618849
# The upper bound for non deterministic is :  0.23293279714827098
# The upper bound for non deterministic is :  0.236162446834504
# The upper bound for non deterministic is :  0.24561479128196656
# The upper bound for non deterministic is :  0.24519785620566031
# The upper bound for non deterministic is :  0.23411794672109343
# The upper bound for non deterministic is :  0.2360749963432497
# The upper bound for non deterministic is :  0.23909540430207815
# The upper bound for non deterministic is :  0.24871488936201297
# The upper bound for non deterministic is :  0.24820357471209048
# The upper bound for non deterministic is :  0.23401491701501542
# The upper bound for non deterministic is :  0.23594583435423544
# The upper bound for non deterministic is :  0.2389853176933982
# The upper bound for non deterministic is :  0.24858635134777562
# The upper bound for non deterministic is :  0.2480654326570676
# The upper bound for non deterministic is :  0.22685568265398776
# The upper bound for non deterministic is :  0.2281858687806309
# The upper bound for non deterministic is :  0.2317299774917993
# The upper bound for non deterministic is :  0.24103027386307296
# The upper bound for non deterministic is :  0.24086735627750766
# The upper bound for non deterministic is :  0.23316325294359053
# The upper bound for non deterministic is :  0.2350575508681807
# The upper bound for non deterministic is :  0.2381461960754745
# The upper bound for non deterministic is :  0.24770393736302987
# The upper bound for non deterministic is :  0.2471718691713659
# The upper bound for non deterministic is :  0.23151537516438053
# The upper bound for non deterministic is :  0.233340390135087
# The upper bound for non deterministic is :  0.23653581226307574
# The upper bound for non deterministic is :  0.24601799993064255
# The upper bound for non deterministic is :  0.2455830319162719
# The upper bound for non deterministic is :  0.22616037849898557
# The upper bound for non deterministic is :  0.22740187157554476
# The upper bound for non deterministic is :  0.23105373194528722
# The upper bound for non deterministic is :  0.24028945332798374
# The upper bound for non deterministic is :  0.24017560385194658
# The upper bound for non deterministic is :  0.23741982154972863
# The upper bound for non deterministic is :  0.23941338813026575
# The upper bound for non deterministic is :  0.23727146122878406
# The upper bound for non deterministic is :  0.2376883754268418
# The upper bound for non deterministic is :  0.23775702334532134
# The upper bound for non deterministic is :  0.24042434825653752
# The upper bound for non deterministic is :  0.24010293566095497
# The upper bound for non deterministic is :  0.23679628720669232
# The upper bound for non deterministic is :  0.23942184343060358
# The upper bound for non deterministic is :  0.2349298356302476
# The upper bound for non deterministic is :  0.239204555792913
# The upper bound for non deterministic is :  0.2349298356302476
# The upper bound for non deterministic is :  0.21541185564837328
# The upper bound for non deterministic is :  0.23275120998506554
# The upper bound for non deterministic is :  0.23274033221337026
# The upper bound for non deterministic is :  0.23220706934023333
# The upper bound for non deterministic is :  0.2112602102913051
# The upper bound for non deterministic is :  0.21496967446555426
# The upper bound for non deterministic is :  0.23251877342648852
# The upper bound for non deterministic is :  0.23250264872785936
# The upper bound for non deterministic is :  0.23193861335128407
# The upper bound for non deterministic is :  0.2109832139741416
# The upper bound for non deterministic is :  0.21156561983202882
# The upper bound for non deterministic is :  0.23072862825031698
# The upper bound for non deterministic is :  0.2306203377364604
# The upper bound for non deterministic is :  0.22980308637448438
# The upper bound for non deterministic is :  0.20814978964562886
# The upper bound for non deterministic is :  0.21725146521893784
# The upper bound for non deterministic is :  0.23373558062598476
# The upper bound for non deterministic is :  0.23374548874832346
# The upper bound for non deterministic is :  0.23331149010363295
# The upper bound for non deterministic is :  0.21244177085586974
# The upper bound for non deterministic is :  0.22244825104536792
# The upper bound for non deterministic is :  0.23680000704205473
# The upper bound for non deterministic is :  0.23681260323878528
# The upper bound for non deterministic is :  0.2365796275379824
# The upper bound for non deterministic is :  0.21752341311107015
# The upper bound for non deterministic is :  0.22223554524088568
# The upper bound for non deterministic is :  0.23666779512889546
# The upper bound for non deterministic is :  0.23668192717203196
# The upper bound for non deterministic is :  0.23644034607479075
# The upper bound for non deterministic is :  0.2172896541357346
# The upper bound for non deterministic is :  0.21012129721344153
# The upper bound for non deterministic is :  0.2295410278052839
# The upper bound for non deterministic is :  0.22931319069101447
# The upper bound for non deterministic is :  0.22829518294309453
# The upper bound for non deterministic is :  0.20631801059310234
# The upper bound for non deterministic is :  0.2207730579935967
# The upper bound for non deterministic is :  0.23577633604183557
# The upper bound for non deterministic is :  0.23579608920785539
# The upper bound for non deterministic is :  0.23550588596086258
# The upper bound for non deterministic is :  0.2156876359048216
# The upper bound for non deterministic is :  0.21792890462945946
# The upper bound for non deterministic is :  0.23411151403388192
# The upper bound for non deterministic is :  0.23412806640145273
# The upper bound for non deterministic is :  0.23372549771024304
# The upper bound for non deterministic is :  0.21287656971564478
# The upper bound for non deterministic is :  0.20928498884794078
# The upper bound for non deterministic is :  0.2289032906012039
# The upper bound for non deterministic is :  0.22858585455341607
# The upper bound for non deterministic is :  0.2274421170021605
# The upper bound for non deterministic is :  0.20529829539003008
# The upper bound for non deterministic is :  0.22972390276732646
# The upper bound for non deterministic is :  0.22798369660635942
# The upper bound for non deterministic is :  0.23339253552141648
# The upper bound for non deterministic is :  0.23040847937460868
# The upper bound for non deterministic is :  0.22999803159898652
# The upper bound for non deterministic is :  0.22804254234470228
# The upper bound for non deterministic is :  0.22693937956982035
# The upper bound for non deterministic is :  0.2310832933186725
# The upper bound for non deterministic is :  0.23156564104809846
# The upper bound for non deterministic is :  0.2307228576320014
# The upper bound for non deterministic is :  0.23050073180848557
# The upper bound for non deterministic is :  0.22693937956982035
# The upper bound for non deterministic is :  0.25659393109500794
# The upper bound for non deterministic is :  0.27415789864914475
# The upper bound for non deterministic is :  0.27601218754556744
# The upper bound for non deterministic is :  0.28298438358986133
# The upper bound for non deterministic is :  0.27475606464809876
# The upper bound for non deterministic is :  0.25620542228456145
# The upper bound for non deterministic is :  0.27364036363177935
# The upper bound for non deterministic is :  0.27561319775401566
# The upper bound for non deterministic is :  0.2827366313373041
# The upper bound for non deterministic is :  0.2742927157037388
# The upper bound for non deterministic is :  0.25315811649165987
# The upper bound for non deterministic is :  0.26936320471394914
# The upper bound for non deterministic is :  0.2723977891641143
# The upper bound for non deterministic is :  0.2808400543284061
# The upper bound for non deterministic is :  0.2705307219129854
# The upper bound for non deterministic is :  0.25822937071534474
# The upper bound for non deterministic is :  0.27630132236431626
# The upper bound for non deterministic is :  0.2776649020924668
# The upper bound for non deterministic is :  0.2840312581696018
# The upper bound for non deterministic is :  0.27664325759088626
# The upper bound for non deterministic is :  0.2630593792347679
# The upper bound for non deterministic is :  0.2822124354870621
# The upper bound for non deterministic is :  0.2824298875889164
# The upper bound for non deterministic is :  0.28728966001792877
# The upper bound for non deterministic is :  0.28198500728049253
# The upper bound for non deterministic is :  0.26285411341340315
# The upper bound for non deterministic is :  0.28197448755494675
# The upper bound for non deterministic is :  0.2822349230811997
# The upper bound for non deterministic is :  0.28714644378287346
# The upper bound for non deterministic is :  0.28176991375167365
# The upper bound for non deterministic is :  0.25105651669982265
# The upper bound for non deterministic is :  0.2663904942053474
# The upper bound for non deterministic is :  0.27010914510705886
# The upper bound for non deterministic is :  0.2795885273437528
# The upper bound for non deterministic is :  0.26784147378080425
# The upper bound for non deterministic is :  0.26148270958615455
# The upper bound for non deterministic is :  0.28035236228052396
# The upper bound for non deterministic is :  0.2808951959107096
# The upper bound for non deterministic is :  0.2861970024647029
# The upper bound for non deterministic is :  0.2802828679861687
# The upper bound for non deterministic is :  0.25882680626719556
# The upper bound for non deterministic is :  0.2770782961846986
# The upper bound for non deterministic is :  0.27827978892306576
# The upper bound for non deterministic is :  0.28443047587480297
# The upper bound for non deterministic is :  0.2773387748982015
# The upper bound for non deterministic is :  0.249891433165215
# The upper bound for non deterministic is :  0.2653302477306768
# The upper bound for non deterministic is :  0.26882953134757104
# The upper bound for non deterministic is :  0.278918454189034
# The upper bound for non deterministic is :  0.26632173177633
# The upper bound for non deterministic is :  0.282766921599922
# The upper bound for non deterministic is :  0.28224181659586567
# The upper bound for non deterministic is :  0.2817592404045473
# The upper bound for non deterministic is :  0.27164047361313015
# The upper bound for non deterministic is :  0.2749949147846674
# The upper bound for non deterministic is :  0.281640626748893
# The upper bound for non deterministic is :  0.27494005165381635
# The upper bound for non deterministic is :  0.2779676664004429
# The upper bound for non deterministic is :  0.27166723791370034
# The upper bound for non deterministic is :  0.2713014654945609
# The upper bound for non deterministic is :  0.2718249657776987
# The upper bound for non deterministic is :  0.2713014654945609
# The upper bound for non deterministic is :  0.24990355583051638
# The upper bound for non deterministic is :  0.25933655624546936
# The upper bound for non deterministic is :  0.2486115725852051
# The upper bound for non deterministic is :  0.2515455507422748
# The upper bound for non deterministic is :  0.2591546152741424
# The upper bound for non deterministic is :  0.24951923390806358
# The upper bound for non deterministic is :  0.259043772987646
# The upper bound for non deterministic is :  0.24812678234301505
# The upper bound for non deterministic is :  0.2510928385686292
# ...
# The upper bound for non deterministic is :  0.20381815061900926
# The upper bound for non deterministic is :  0.1935584139684347
# The upper bound for non deterministic is :  0.1935584139684347
# The upper bound for non deterministic is :  0.19497260599387595
# The upper bound for non deterministic is :  0.19816400639666393
# The upper bound for non deterministic is :  0.2041314643526408
# The upper bound for non deterministic is :  0.18797651199831183
# The upper bound for non deterministic is :  0.197811257161778
# The upper bound for non deterministic is :  0.19437289449155276
# The upper bound for non deterministic is :  0.1975840305779361
# The upper bound for non deterministic is :  0.20349542289548272
# The upper bound for non deterministic is :  0.1874454876456188
# The upper bound for non deterministic is :  0.1973291760437728
# The upper bound for non deterministic is :  0.19010994765274003
# The upper bound for non deterministic is :  0.19307130504852976
# The upper bound for non deterministic is :  0.1987997235635362
# The upper bound for non deterministic is :  0.18296049442120155
# The upper bound for non deterministic is :  0.1930632108225651
# The upper bound for non deterministic is :  0.19729038834081303
# The upper bound for non deterministic is :  0.200526249384066
# The upper bound for non deterministic is :  0.20656174574778446
# The upper bound for non deterministic is :  0.19032732322960527
# The upper bound for non deterministic is :  0.2001037959691539
# The upper bound for non deterministic is :  0.20423313789967118
# The upper bound for non deterministic is :  0.20759567784707
# The upper bound for non deterministic is :  0.21370421066274187
# The upper bound for non deterministic is :  0.1972499194560512
# The upper bound for non deterministic is :  0.20685027972144088
# The upper bound for non deterministic is :  0.20395679313189063
# The upper bound for non deterministic is :  0.20735713861568028
# The upper bound for non deterministic is :  0.21341649158325376
# The upper bound for non deterministic is :  0.1969423581984655
# The upper bound for non deterministic is :  0.2065463901906106
# The upper bound for non deterministic is :  0.1872269307550311
# The upper bound for non deterministic is :  0.19002254655803308
# The upper bound for non deterministic is :  0.19560101998687568
# The upper bound for non deterministic is :  0.17994293299594316
# The upper bound for non deterministic is :  0.19019763370209686
# The upper bound for non deterministic is :  0.2019727888572206
# The upper bound for non deterministic is :  0.20531164977554223
# The upper bound for non deterministic is :  0.2113739121861018
# The upper bound for non deterministic is :  0.19500560353816931
# The upper bound for non deterministic is :  0.20461406701954094
# The upper bound for non deterministic is :  0.1981640006761134
# The upper bound for non deterministic is :  0.20140233720619471
# The upper bound for non deterministic is :  0.20750782765962644
# The upper bound for non deterministic is :  0.19117648168671175
# The upper bound for non deterministic is :  0.200941688307748
# The upper bound for non deterministic is :  0.18555695656129434
# The upper bound for non deterministic is :  0.18840559524234518
# The upper bound for non deterministic is :  0.19380149527765012
# The upper bound for non deterministic is :  0.17830578738408331
# The upper bound for non deterministic is :  0.18859954917475863
# The upper bound for non deterministic is :  0.20553822303946528
# The upper bound for non deterministic is :  0.2030880535540449
# The upper bound for non deterministic is :  0.1899818424608779
# The upper bound for non deterministic is :  0.2005734556179476
# The upper bound for non deterministic is :  0.19114047193712652
# The upper bound for non deterministic is :  0.19168562325918653
# The upper bound for non deterministic is :  0.20436291552740438
# The upper bound for non deterministic is :  0.19826209296148234
# The upper bound for non deterministic is :  0.19049246922606566
# The upper bound for non deterministic is :  0.19000411646596477
# The upper bound for non deterministic is :  0.18967649821596655
# The upper bound for non deterministic is :  0.18967649821596655
# The upper bound for non deterministic is :  0.207902587071301
# The upper bound for non deterministic is :  0.19699448419877952
# The upper bound for non deterministic is :  0.20318551698482035
# The upper bound for non deterministic is :  0.20578052727563134
# The upper bound for non deterministic is :  0.19929700159122005
# The upper bound for non deterministic is :  0.20736604421903004
# The upper bound for non deterministic is :  0.19644234155417256
# The upper bound for non deterministic is :  0.2026240698354213
# The upper bound for non deterministic is :  0.2052180789822357
# The upper bound for non deterministic is :  0.19874195532068972
# The upper bound for non deterministic is :  0.20316397771322942
# The upper bound for non deterministic is :  0.1923488801392822
# The upper bound for non deterministic is :  0.19831487684013216
# The upper bound for non deterministic is :  0.20105527011901164
# The upper bound for non deterministic is :  0.19455046712660262
# The upper bound for non deterministic is :  0.21014761254618675
# The upper bound for non deterministic is :  0.19920416296523025
# The upper bound for non deterministic is :  0.2054319118388449
# The upper bound for non deterministic is :  0.20799553571433632
# The upper bound for non deterministic is :  0.20152195324088246
# The upper bound for non deterministic is :  0.21671342341902267
# The upper bound for non deterministic is :  0.20573503152298794
# The upper bound for non deterministic is :  0.21204213996934806
# The upper bound for non deterministic is :  0.21449984440937347
# The upper bound for non deterministic is :  0.20825664744402245
# The upper bound for non deterministic is :  0.21644510472249873
# The upper bound for non deterministic is :  0.20544233613467555
# The upper bound for non deterministic is :  0.21175664869571342
# The upper bound for non deterministic is :  0.21425302928055756
# The upper bound for non deterministic is :  0.20793070062882352
# The upper bound for non deterministic is :  0.20029510714140097
# The upper bound for non deterministic is :  0.1895224898738786
# The upper bound for non deterministic is :  0.19541446356754671
# The upper bound for non deterministic is :  0.19826732038684503
# The upper bound for non deterministic is :  0.19169236023511754
# The upper bound for non deterministic is :  0.21460596354214778
# The upper bound for non deterministic is :  0.20363232410090254
# The upper bound for non deterministic is :  0.20991156382918752
# The upper bound for non deterministic is :  0.21238133032548517
# The upper bound for non deterministic is :  0.20604775678498644
# The upper bound for non deterministic is :  0.21101951086192638
# The upper bound for non deterministic is :  0.20004424105319818
# The upper bound for non deterministic is :  0.20629596825911284
# The upper bound for non deterministic is :  0.20881961437088897
# The upper bound for non deterministic is :  0.2024493872722674
# The upper bound for non deterministic is :  0.19870458520046408
# The upper bound for non deterministic is :  0.18799788076438645
# The upper bound for non deterministic is :  0.19380688847852873
# The upper bound for non deterministic is :  0.1967224374217662
# The upper bound for non deterministic is :  0.19018223382990163
# The upper bound for non deterministic is :  0.2109536549231738
# The upper bound for non deterministic is :  0.20242947919366128
# The upper bound for non deterministic is :  0.2080708862557734
# The upper bound for non deterministic is :  0.2110278785269175
# The upper bound for non deterministic is :  0.19930088592467327
# The upper bound for non deterministic is :  0.2059098801290044
# The upper bound for non deterministic is :  0.20588540172044573
# The upper bound for non deterministic is :  0.20963374846727284
# The upper bound for non deterministic is :  0.19776816249990004
# The upper bound for non deterministic is :  0.2039491204513389
# The upper bound for non deterministic is :  0.19875814895540928
# The upper bound for non deterministic is :  0.19776816249990004
# The upper bound for non deterministic is :  0.19527326030263248
# The upper bound for non deterministic is :  0.19573198567759426
# The upper bound for non deterministic is :  0.18825179086238142
# The upper bound for non deterministic is :  0.20521223858795518
# The upper bound for non deterministic is :  0.18440655139819767
# The upper bound for non deterministic is :  0.19471444892273954
# The upper bound for non deterministic is :  0.19515471379424698
# The upper bound for non deterministic is :  0.18772034476590482
# The upper bound for non deterministic is :  0.204650231596816
# The upper bound for non deterministic is :  0.18378068086863397
# The upper bound for non deterministic is :  0.19016920675363164
# The upper bound for non deterministic is :  0.19067254962873553
# The upper bound for non deterministic is :  0.183134988483947
# The upper bound for non deterministic is :  0.20006833069864322
# The upper bound for non deterministic is :  0.17923564641724066
# The upper bound for non deterministic is :  0.1976000519501394
# The upper bound for non deterministic is :  0.19810890182941837
# The upper bound for non deterministic is :  0.19068825889358904
# The upper bound for non deterministic is :  0.20763851172956216
# The upper bound for non deterministic is :  0.18685251532055258
# The upper bound for non deterministic is :  0.20487618539592806
# The upper bound for non deterministic is :  0.20510252310872534
# The upper bound for non deterministic is :  0.19789197685482074
# The upper bound for non deterministic is :  0.21466279397477028
# The upper bound for non deterministic is :  0.19415718222577366
# The upper bound for non deterministic is :  0.2045933354259049
# The upper bound for non deterministic is :  0.2048426952024074
# The upper bound for non deterministic is :  0.19763536514247515
# The upper bound for non deterministic is :  0.21439448814423456
# The upper bound for non deterministic is :  0.19384171780952864
# The upper bound for non deterministic is :  0.18712213417307777
# The upper bound for non deterministic is :  0.18756671202593367
# The upper bound for non deterministic is :  0.17996320275028688
# The upper bound for non deterministic is :  0.19699852511674432
# The upper bound for non deterministic is :  0.17609405185723365
# The upper bound for non deterministic is :  0.20256262627557026
# The upper bound for non deterministic is :  0.20283407681115856
# The upper bound for non deterministic is :  0.1955496795762891
# The upper bound for non deterministic is :  0.21240250426416973
# The upper bound for non deterministic is :  0.19179813250609734
# The upper bound for non deterministic is :  0.19860697844148278
# The upper bound for non deterministic is :  0.19902747772918422
# The upper bound for non deterministic is :  0.19163600396436126
# The upper bound for non deterministic is :  0.2085397435628662
# The upper bound for non deterministic is :  0.18781970895068945
# The upper bound for non deterministic is :  0.1854273792525059
# The upper bound for non deterministic is :  0.18587421315097602
# The upper bound for non deterministic is :  0.1782981781299257
# The upper bound for non deterministic is :  0.1953049805011673
# The upper bound for non deterministic is :  0.1745553146661843
# The upper bound for non deterministic is :  0.20249510816929384
# The upper bound for non deterministic is :  0.18191770004727792
# The upper bound for non deterministic is :  0.19241626120142835
# The upper bound for non deterministic is :  0.1830636058888156
# The upper bound for non deterministic is :  0.19868742569886005
# The upper bound for non deterministic is :  0.199640342337155
# The upper bound for non deterministic is :  0.19920261347967766
# The upper bound for non deterministic is :  0.20022050783472467
# The upper bound for non deterministic is :  0.19487399639010844
# The upper bound for non deterministic is :  0.201136790676899
# The upper bound for non deterministic is :  0.19268842027912553
# The upper bound for non deterministic is :  0.18191770004727792
# The upper bound for non deterministic is :  0.18370843509035362
# The upper bound for non deterministic is :  0.1884044762726853
# The upper bound for non deterministic is :  0.19748723185823092
# The upper bound for non deterministic is :  0.19547456713720862
# The upper bound for non deterministic is :  0.19029138645345928
# The upper bound for non deterministic is :  0.18313963345010398
# The upper bound for non deterministic is :  0.1878119381356999
# The upper bound for non deterministic is :  0.19689114285303227
# The upper bound for non deterministic is :  0.1949021178575635
# The upper bound for non deterministic is :  0.18974539083356862
# The upper bound for non deterministic is :  0.1785509672538193
# The upper bound for non deterministic is :  0.18314444443726585
# The upper bound for non deterministic is :  0.1922659767053016
# The upper bound for non deterministic is :  0.19068504269347913
# The upper bound for non deterministic is :  0.18537983204550051
# The upper bound for non deterministic is :  0.1861264723331597
# The upper bound for non deterministic is :  0.1908633679133524
# The upper bound for non deterministic is :  0.19998348656767156
# The upper bound for non deterministic is :  0.19780370505541978
# The upper bound for non deterministic is :  0.19262348356294934
# The upper bound for non deterministic is :  0.19344014542420773
# The upper bound for non deterministic is :  0.19824082258079329
# The upper bound for non deterministic is :  0.2076113310567687
# The upper bound for non deterministic is :  0.20459134318578476
# The upper bound for non deterministic is :  0.19955420076355435
# The upper bound for non deterministic is :  0.19312484128172158
# The upper bound for non deterministic is :  0.1979422033738299
# The upper bound for non deterministic is :  0.2072598070422242
# The upper bound for non deterministic is :  0.20433172630116136
# The upper bound for non deterministic is :  0.19928784361697927
# The upper bound for non deterministic is :  0.17548692094779605
# The upper bound for non deterministic is :  0.18011998687528852
# The upper bound for non deterministic is :  0.18914281109194458
# The upper bound for non deterministic is :  0.187824035882526
# The upper bound for non deterministic is :  0.18245997684535487
# The upper bound for non deterministic is :  0.19101062292340315
# The upper bound for non deterministic is :  0.19590139001492157
# The upper bound for non deterministic is :  0.20512921182835875
# The upper bound for non deterministic is :  0.2024679685024302
# The upper bound for non deterministic is :  0.19727865718853987
# The upper bound for non deterministic is :  0.18709743705404835
# The upper bound for non deterministic is :  0.19180929869562324
# The upper bound for non deterministic is :  0.20095016779648622
# The upper bound for non deterministic is :  0.19864995142717085
# The upper bound for non deterministic is :  0.19348297031970257
# The upper bound for non deterministic is :  0.17382074380332374
# The upper bound for non deterministic is :  0.178448384168098
# The upper bound for non deterministic is :  0.18738525911527626
# The upper bound for non deterministic is :  0.18624208713944346
# The upper bound for non deterministic is :  0.18091084109749
# The upper bound for non deterministic is :  0.19984240009167276
# The upper bound for non deterministic is :  0.18915825718423995
# The upper bound for non deterministic is :  0.19694046811971755
# The upper bound for non deterministic is :  0.1923381133025408
# The upper bound for non deterministic is :  0.17988545745695517
# The upper bound for non deterministic is :  0.18767470620307114
# The upper bound for non deterministic is :  0.19113537571071937
# The upper bound for non deterministic is :  0.19261618477109843
# The upper bound for non deterministic is :  0.18906650926278828
# The upper bound for non deterministic is :  0.1869708277866629
# The upper bound for non deterministic is :  0.18690481207264104
# The upper bound for non deterministic is :  0.17988545745695517

# %%
dfCV.style.set_caption('RandomGridCV Results').set_properties(
    **{'background-color': ''}, subset=['error', 'time'])
# Out:
# <style type="text/css">
# #T_80de3_row0_col1, #T_80de3_row0_col4, #T_80de3_row1_col1, #T_80de3_row1_col4, #T_80de3_row2_col1, #T_80de3_row2_col4, #T_80de3_row3_col1, #T_80de3_row3_col4, #T_80de3_row4_col1, #T_80de3_row4_col4 {
#   background-color: ;
# }
# </style>
# <table id="T_80de3">
#   <caption>RandomGridCV Results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80de3_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_80de3_level0_col1" class="col_heading level0 col1" >error</th>
#       <th id="T_80de3_level0_col2" class="col_heading level0 col2" >s</th>
#       <th id="T_80de3_level0_col3" class="col_heading level0 col3" >upper</th>
#       <th id="T_80de3_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80de3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80de3_row0_col0" class="data row0 col0" >mammographic</td>
#       <td id="T_80de3_row0_col1" class="data row0 col1" >0.212 ± 0.024</td>
#       <td id="T_80de3_row0_col2" class="data row0 col2" >0.433 ± 0.0689</td>
#       <td id="T_80de3_row0_col3" class="data row0 col3" >0.227 ± 0.0126</td>
#       <td id="T_80de3_row0_col4" class="data row0 col4" >36.7 ± 0.365</td>
#     </tr>
#     <tr>
#       <th id="T_80de3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80de3_row1_col0" class="data row1 col0" >haberman</td>
#       <td id="T_80de3_row1_col1" class="data row1 col1" >0.274 ± 0.0481</td>
#       <td id="T_80de3_row1_col2" class="data row1 col2" >0.531 ± 0.0696</td>
#       <td id="T_80de3_row1_col3" class="data row1 col3" >0.271 ± 0.0162</td>
#       <td id="T_80de3_row1_col4" class="data row1 col4" >30.4 ± 0.277</td>
#     </tr>
#     <tr>
#       <th id="T_80de3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80de3_row2_col0" class="data row2 col0" >indian_liver</td>
#       <td id="T_80de3_row2_col1" class="data row2 col1" >0.288 ± 0.0179</td>
#       <td id="T_80de3_row2_col2" class="data row2 col2" >0.44 ± 0.0487</td>
#       <td id="T_80de3_row2_col3" class="data row2 col3" >0.296 ± 0.00526</td>
#       <td id="T_80de3_row2_col4" class="data row2 col4" >37.6 ± 0.422</td>
#     </tr>
#     <tr>
#       <th id="T_80de3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80de3_row3_col0" class="data row3 col0" >diabetes</td>
#       <td id="T_80de3_row3_col1" class="data row3 col1" >0.277 ± 0.0302</td>
#       <td id="T_80de3_row3_col2" class="data row3 col2" >0.48 ± 0.0942</td>
#       <td id="T_80de3_row3_col3" class="data row3 col3" >0.288 ± 0.00768</td>
#       <td id="T_80de3_row3_col4" class="data row3 col4" >37.2 ± 0.703</td>
#     </tr>
#     <tr>
#       <th id="T_80de3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80de3_row4_col0" class="data row4 col0" >credit</td>
#       <td id="T_80de3_row4_col1" class="data row4 col1" >0.205 ± 0.0247</td>
#       <td id="T_80de3_row4_col2" class="data row4 col2" >0.512 ± 0.0759</td>
#       <td id="T_80de3_row4_col3" class="data row4 col3" >0.2 ± 0.00776</td>
#       <td id="T_80de3_row4_col4" class="data row4 col4" >34.5 ± 0.157</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfUpper.style.set_caption('RandomGridUpper Results').set_properties(
    **{'background-color': ''}, subset=['error', 'time'])
# Out:
# <style type="text/css">
# #T_5a12e_row0_col1, #T_5a12e_row0_col4, #T_5a12e_row1_col1, #T_5a12e_row1_col4, #T_5a12e_row2_col1, #T_5a12e_row2_col4, #T_5a12e_row3_col1, #T_5a12e_row3_col4, #T_5a12e_row4_col1, #T_5a12e_row4_col4 {
#   background-color: ;
# }
# </style>
# <table id="T_5a12e">
#   <caption>RandomGridUpper Results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a12e_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_5a12e_level0_col1" class="col_heading level0 col1" >error</th>
#       <th id="T_5a12e_level0_col2" class="col_heading level0 col2" >s</th>
#       <th id="T_5a12e_level0_col3" class="col_heading level0 col3" >upper</th>
#       <th id="T_5a12e_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a12e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a12e_row0_col0" class="data row0 col0" >mammographic</td>
#       <td id="T_5a12e_row0_col1" class="data row0 col1" >0.216 ± 0.0222</td>
#       <td id="T_5a12e_row0_col2" class="data row0 col2" >0.329 ± 0.025</td>
#       <td id="T_5a12e_row0_col3" class="data row0 col3" >0.224 ± 0.0125</td>
#       <td id="T_5a12e_row0_col4" class="data row0 col4" >8.28 ± 0.103</td>
#     </tr>
#     <tr>
#       <th id="T_5a12e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a12e_row1_col0" class="data row1 col0" >haberman</td>
#       <td id="T_5a12e_row1_col1" class="data row1 col1" >0.283 ± 0.0502</td>
#       <td id="T_5a12e_row1_col2" class="data row1 col2" >0.338 ± 0.0262</td>
#       <td id="T_5a12e_row1_col3" class="data row1 col3" >0.261 ± 0.0153</td>
#       <td id="T_5a12e_row1_col4" class="data row1 col4" >6.87 ± 0.105</td>
#     </tr>
#     <tr>
#       <th id="T_5a12e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a12e_row2_col0" class="data row2 col0" >indian_liver</td>
#       <td id="T_5a12e_row2_col1" class="data row2 col1" >0.288 ± 0.0185</td>
#       <td id="T_5a12e_row2_col2" class="data row2 col2" >0.339 ± 0.028</td>
#       <td id="T_5a12e_row2_col3" class="data row2 col3" >0.293 ± 0.00625</td>
#       <td id="T_5a12e_row2_col4" class="data row2 col4" >8.71 ± 0.175</td>
#     </tr>
#     <tr>
#       <th id="T_5a12e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a12e_row3_col0" class="data row3 col0" >diabetes</td>
#       <td id="T_5a12e_row3_col1" class="data row3 col1" >0.294 ± 0.0401</td>
#       <td id="T_5a12e_row3_col2" class="data row3 col2" >0.337 ± 0.035</td>
#       <td id="T_5a12e_row3_col3" class="data row3 col3" >0.281 ± 0.00758</td>
#       <td id="T_5a12e_row3_col4" class="data row3 col4" >8.53 ± 0.0622</td>
#     </tr>
#     <tr>
#       <th id="T_5a12e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a12e_row4_col0" class="data row4 col0" >credit</td>
#       <td id="T_5a12e_row4_col1" class="data row4 col1" >0.199 ± 0.0287</td>
#       <td id="T_5a12e_row4_col2" class="data row4 col2" >0.331 ± 0.0286</td>
#       <td id="T_5a12e_row4_col3" class="data row4 col3" >0.188 ± 0.00827</td>
#       <td id="T_5a12e_row4_col4" class="data row4 col4" >8.04 ± 0.0954</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results
# Comparing the resulting tables above we notice that both methods:
# RandomGridCV and Random Grid using Upper bounds are really similar in
# performance, one can do better than the other depending on the datasets but
# have overall the same error range.
#
# Furthermore we can see how using the Upper bounds results in a great
# improvement in the running time being around 4 times quicker than
# the usual RandomGrid method.
#
# We note that in every dataset the optimum value for the parameter s seems
# to be  always around 0.3, that is why this value has been chosen to be
# the default value for the library.
